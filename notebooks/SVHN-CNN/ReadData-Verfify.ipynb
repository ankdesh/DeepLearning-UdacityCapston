# %%
import h5py

# %matplotlib inline

# %%
h5f = h5py.File('svhn_2.h5','r')

# %%
imgs = h5f['images']
labels = h5f['digits']

# %%
print (imgs[0].shape)
# Out:
# (32, 64, 3)

# %%
print (labels[0])
plt.imshow(imgs[0])
# Out:
# [3 8]
