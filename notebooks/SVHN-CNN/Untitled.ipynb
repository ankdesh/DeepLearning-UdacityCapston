# %%
from __future__ import division, print_function, absolute_import

import tflearn
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.conv import conv_2d, max_pool_2d
from tflearn.layers.normalization import local_response_normalization
from tflearn.layers.estimator import regression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import LoadDataset
# %matplotlib inline

# %%
asd = LoadDataset.getDataSet(10,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e6587d52cac1> in <module>()
# ----> 1 asd = LoadDataset.getDataSet(10,3)
#
# /home/ankdesh/explore/DeepLearning-UdacityCapston/notebooks/SVHN-CNN/LoadDataset.py in getDataSet(numDataPoints, maxDigits)
#     115
#     116     for idx in range(numDataPoints):
# --> 117         sample_point = getNextImage(DATA_FOLDER).next()
#     118         images[idx] = sample_point[0]
#     119         digits[idx] = pad_sequences(sample_point[1], maxlen = maxDigits)
#
# /home/ankdesh/explore/DeepLearning-UdacityCapston/notebooks/SVHN-CNN/LoadDataset.py in getNextImage(dirName)
#      99     for imgFile in allFileNames:
#     100         img = Image.open(imgFile)
# --> 101         labels = [int(x['label']) for x in train_data[os.path.split(imgFile)[1]]]
#     102         img = img.resize((IMG_WIDTH,IMG_HEIGHT), resample = (Image.BILINEAR))
#     103         #my_img = tf.image.decode_png(imgFile)
#
# NameError: global name 'train_data' is not defined

# %%
bsd = asd[0]
#print (bsd[1])
plt.imshow(bsd[0])
print (bsd[0].shape)
print (bsd[1])
# Out:
# (64, 128, 3)
# [2, 5]

# %%
def dense_to_one_hot(labels_dense, num_classes=10):
    """Convert class labels from scalars to one-hot vectors."""
    num_labels = labels_dense.shape[0]
    index_offset = np.arange(num_labels) * num_classes
    labels_one_hot = np.zeros((num_labels, num_classes))
    labels_one_hot.flat[index_offset + labels_dense.ravel()] = 1
    return labels_one_hot
